# %% [markdown]
# # USA Data Collection
#
# Loads embedded BLS OES 2023 data from `src/usa_data.py` and writes `data/processed/merged_usa_data.csv`.

# %%
import sys
from pathlib import Path
ROOT = Path().resolve().parent
sys.path.insert(0, str(ROOT / 'src'))

import pandas as pd
from usa_data import get_merged_usa_data

# %%
df = get_merged_usa_data()
print(f'USA data: {len(df)} rows, {len(df.columns)} columns')
print(f'Roles: {sorted(df["role"].unique())}')
print(f'Career stages: {sorted(df["career_stage"].unique())}')
df.head()
# Out:
# USA data: 30 rows, 19 columns
# Roles: ['civil_engineer', 'construction_laborer', 'farm_worker', 'financial_analyst', 'lawyer', 'manufacturing_worker', 'physician', 'registered_nurse', 'retail_worker', 'software_engineer']
# Career stages: ['entry', 'mid', 'senior']
#                 role sector career_stage  median_salary_local  wage_2019  \
# 0  software_engineer   tech        entry                73670     107900
# 1  software_engineer   tech          mid               130160     107900
# 2  software_engineer   tech       senior               208620     107900
# 3             lawyer  legal        entry                64150     122960
# 4             lawyer  legal          mid               145760     122960
#
#    wage_2020  wage_2021  wage_2022  wage_2023  emp_2019  emp_2020  emp_2021  \
# 0     110140     120730     127260     130160      1775      1731      1688
# 1     110140     120730     127260     130160      1775      1731      1688
# 2     110140     120730     127260     130160      1775      1731      1688
# 3     126930     127990     136260     145760       670       665       682
# 4     126930     127990     136260     145760       670       665       682
#
#    emp_2022  emp_2023  median_salary_ppp_usd  median_salary_usd  \
# 0      1795      1825                73670.0            73670.0
# 1      1795      1825               130160.0           130160.0
# 2      1795      1825               208620.0           208620.0
# 3       691       698                64150.0            64150.0
# 4       691       698               145760.0           145760.0
#
#    employed_thousands  yoy_wage_growth_pct country
# 0                1825                 2.28     USA
# 1                1825                 2.28     USA
# 2                1825                 2.28     USA
# 3                 698                 6.97     USA
# 4                 698                 6.97     USA

# %%
out = ROOT / 'data' / 'processed' / 'merged_usa_data.csv'
df.to_csv(out, index=False)
print(f'Wrote {len(df)} rows to {out}')
print(df.columns.tolist())
# Out:
# Wrote 30 rows to /Users/mckornfield/repo/homelessness-stats/software-stats/data/processed/merged_usa_data.csv
# ['role', 'sector', 'career_stage', 'median_salary_local', 'wage_2019', 'wage_2020', 'wage_2021', 'wage_2022', 'wage_2023', 'emp_2019', 'emp_2020', 'emp_2021', 'emp_2022', 'emp_2023', 'median_salary_ppp_usd', 'median_salary_usd', 'employed_thousands', 'yoy_wage_growth_pct', 'country']
